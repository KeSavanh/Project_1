# %%
# Dependencies
import matplotlib.pyplot as plt
import requests
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-feed68817001> in <module>
#       3 import requests
#       4 import pandas as pd
# ----> 5 from config import api_key
#
# ImportError: cannot import name 'api_key'

# %%
weather_df = pd.read_csv('storm_data_search_results.csv')

# %%
weather_df.head()
# Out:
#    EVENT_ID                                        CZ_NAME_STR BEGIN_LOCATION  \
# 0    149369  SAN BERNARDINO AND RIVERSIDE COUNTY VALLEYS - ...
# 1    149364                   APPLE AND LUCERNE VALLEYS (ZONE)
# 2    149370             SAN BERNARDINO COUNTY MOUNTAINS (ZONE)
# 3    149368                  RIVERSIDE COUNTY MOUNTAINS (ZONE)
# 4    149367                 ORANGE COUNTY COASTAL AREAS (ZONE)
#
#    BEGIN_DATE  BEGIN_TIME EVENT_TYPE MAGNITUDE TOR_F_SCALE  DEATHS_DIRECT  \
# 0  01/01/2009           0    Drought                                    0
# 1  01/01/2009           0    Drought                                    0
# 2  01/01/2009           0    Drought                                    0
# 3  01/01/2009           0    Drought                                    0
# 4  01/01/2009           0    Drought                                    0
#
#    INJURIES_DIRECT  ...  END_LOCATION    END_DATE END_TIME BEGIN_LAT  \
# ...
